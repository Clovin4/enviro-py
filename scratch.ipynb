# %% [markdown]
#  # Extract

# %%
import pandas as pd
import numpy as np
import pytz as tz
import json
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
from noaa_sdk import NOAA

# %%
from etl.extract import Extract
from etl.transform import Transform
from etl.load import Load

# %%
ex = Extract()
tr = Transform()
ld = Load()
dfs = ex.get_weather('70119')
dfs = tr.transform(dfs)

# %%
dfs['70119']
# Out:
#                     startTime                   endTime  isDaytime  \
# 0   2023-08-03 16:00:00+00:00 2023-08-03 17:00:00+00:00       True
# 1   2023-08-03 17:00:00+00:00 2023-08-03 18:00:00+00:00       True
# 2   2023-08-03 18:00:00+00:00 2023-08-03 19:00:00+00:00       True
# 3   2023-08-03 19:00:00+00:00 2023-08-03 20:00:00+00:00       True
# 4   2023-08-03 20:00:00+00:00 2023-08-03 21:00:00+00:00       True
# ..                        ...                       ...        ...
# 151 2023-08-09 23:00:00+00:00 2023-08-10 00:00:00+00:00      False
# 152 2023-08-10 00:00:00+00:00 2023-08-10 01:00:00+00:00      False
# 153 2023-08-10 01:00:00+00:00 2023-08-10 02:00:00+00:00      False
# 154 2023-08-10 02:00:00+00:00 2023-08-10 03:00:00+00:00      False
# 155 2023-08-10 03:00:00+00:00 2023-08-10 04:00:00+00:00      False
#
#      temperature temperatureUnit temperatureTrend windSpeed windDirection  \
# 0             91               F             None     5 mph             N
# ...

# %%
dfs.keys()
# Out:
# dict_keys(['70119'])

# %%
dfs['70119'].sort_values(by='startTime').head()
# Out:
#                   startTime                   endTime  isDaytime  temperature  \
# 0 2023-08-03 16:00:00+00:00 2023-08-03 17:00:00+00:00       True           91
# 1 2023-08-03 17:00:00+00:00 2023-08-03 18:00:00+00:00       True           92
# 2 2023-08-03 18:00:00+00:00 2023-08-03 19:00:00+00:00       True           93
# 3 2023-08-03 19:00:00+00:00 2023-08-03 20:00:00+00:00       True           94
# 4 2023-08-03 20:00:00+00:00 2023-08-03 21:00:00+00:00       True           94
#
#   temperatureUnit temperatureTrend windSpeed windDirection shortForecast  \
# 0               F             None     5 mph             N         Sunny
# 1               F             None     5 mph             N         Sunny
# 2               F             None     5 mph             N  Mostly Sunny
# 3               F             None     5 mph             N  Mostly Sunny
# 4               F             None    10 mph            NE  Mostly Sunny
#
# ...
